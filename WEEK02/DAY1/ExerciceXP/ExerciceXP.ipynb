# %% [markdown]
# #EXERCICE 1
#
# 	L'analyse de données est un processus d' inspection, de nettoyage, de transformation et de modélisation des données visant à en extraire
# 	des informations utiles, à éclairer les conclusions et à faciliter la prise de décision. L'analyse des données fait appel à diverses techniques et outils, allant de l'analyse statistique de base aux algorithmes complexes et aux modèles prédictifs et comporte plusieurs branches en son sein tel que la description, l'analytique, la prédiction et la prescription.
#
# 	L'analyse des données joue un rôle important dans le commerce, les sciences, l'ingénierie et les sciences sociales, permettant aux organisations et aux individus de prendre des décisions fondées sur les données.
# l'analyse des données est bien plus qu'un simple processus, c'est une nécessité pour une bonne prise de décision et une planification stratégique.
#
# 	L'analyse des données, s'applique dans :
#
# Stratégie pour les entreprises :
# Aider les entreprises à prendre des décisions fondées sur les données, et voir comment se comporte le marché pour essayer de prédire les tendances.
#
# Recherche scientifique :
# Contribuer à la vérification des hypothèses et à la découverte, permet aussi de tester des molécules avancées.
#
# Politiques publiques :
# Contribuer à l'élaboration de politiques fondées sur des données probantes, pour les sondages politiques pour voir la côte de popularité des candidats et des partis.

# %%
#EXERICE 2
import pandas as pd

# Donnée à Importer
df = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Time Americans Spend Sleeping.csv')
da = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Mental health Depression disorder Data.csv')
db = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\clean_dataset.csv')
dc = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\crx.csv')

# 5 Premières lignes
display(df.head())
display(da.head())
display(db.head())
display(dc.head())

# %% [markdown]
# # Description EXERCICE 1 :
#     df — Time Americans Spend Sleeping:
#     Contient des données sur le temps de sommeil des Américains.
#     Variables : tranches d'âge, sexe, durée de sommeil (en minutes/heures).
#     Utilité : analyser les habitudes de sommeil selon les profils démographiques.
#
#     da — Mental Health Depression Disorder:
#     Dataset mondial sur les troubles dépressifs et de santé mentale.
#     Variables : pays, année, prévalence des troubles (%), population concernée.
#     Utilité : étudier l'évolution des troubles mentaux par pays et dans le temps.
#
#     db — Clean Dataset:
#     Dataset pré-nettoyé, prêt pour l'analyse ou la modélisation.
#     Variables : à explorer selon le contenu (données génériques nettoyées).
#     Utilité : entraînement de modèles ML sans étape de nettoyage préalable.
#
#     dc — CRX Dataset:
#     Dataset de demandes de crédit (Credit Approval — UCI Repository).
#     Variables : attributs anonymisés (A1 à A16), cible : approbation crédit (+ / -).
#     Utilité : classification binaire pour prédire l'acceptation ou le refus de crédit.

# %%
#EXERCICE 3

df = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Time Americans Spend Sleeping.csv')
da = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Mental health Depression disorder Data.csv')
db = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\clean_dataset.csv')
dc = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\crx.csv')

for nom, dataset in [("Sleeping", df), ("Depression", da), ("Clean", db), ("CRX", dc)]:
    print(f"\n--- {nom} ---")
    for col in dataset.columns:
        if dataset[col].dtype == 'object':
            print(f"{col} : Qualitative")
        else:
            print(f"{col} : Quantitative")
            
print(df.dtypes)
print(da.dtypes)
print(db.dtypes)
print(dc.dtypes)

# %% [markdown]
# #description EXERCICE 3 :
# #Si la colonne contient du texte (object) elle sera nommée comme Qualitative
# #Si la colonne contient des nombres (int64 ou float64) elle sera nommée comme Quantitative

# %%
#EXERCICE 4

dp = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Iris.csv')

# Aperçu
print("=== Premières lignes ===")
print(df.head())

print("\n=== Types de colonnes ===")
print(df.dtypes)

# Catégorisation
print("\n=== Catégorisation ===")
for col in df.columns:
    if df[col].dtype == 'object':
        print(f"{col} : Qualitative")
    else:
        print(f"{col} : Quantitative")

# %% [markdown]
# #Description EXERCICE 4 :
# # sepal_length estQuantitative parceque C'est une mesure en cm
# # sepal_width est Quantitative parceque C'est une mesure en cm
# # petal_length est Quantitative parceque C'est une mesure en cm
# # petal_width est Quantitative parceque C'est une mesure en cm
# # species est Qualitative parceque C'est un nom d'espèce

# %%
#EXERCICE 5

df = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\Time Americans Spend Sleeping.csv')

print("Premières lignes")
print(df.head())

print("\n Colonnes disponibles")
print(df.columns.tolist())

print("\n Types de données")
print(df.dtypes)

print("\n Statistiques de base")
print(df.describe())

# %%
#EXERCICE 6

import pandas as pd

# Données de l'exercice
data = {
    "Source de données": [
        "Rapports financiers dans Excel",
        "Photographies sur réseaux sociaux",
        "Articles de presse sur un site web",
        "Données d'inventaire en base relationnelle",
        "Enregistrements d'entretiens"
    ],
    "Type": [
        "Structurées",
        "Non structurées",
        "Non structurées",
        "Structurées",
        "Non structurées"
    ],
}

df = pd.DataFrame(data)
display(df)

# %%
#EXERCICE 7

import pandas as pd

data = {
    "Source non structurée": [
        "Articles de blog sur les voyages",
        "Enregistrements audio service client",
        "Notes manuscrites brainstorming",
        "Tutoriel vidéo cuisine"
    ],
    "Méthode de conversion": [
        "Web Scraping + NLP",
        "Speech-to-Text + NLP",
        "OCR (reconnaissance de texte)",
        "Transcription vidéo + NLP"
    ],
    "Résultat structuré": [
        "Tableau : destination, date, note, mots-clés",
        "Tableau : durée, sujet, sentiment, problème",
        "Tableau : idée, catégorie, priorité, auteur",
        "Tableau : étape, ingrédient, durée, action"
    ],
}

df = pd.DataFrame(data)
display(df)

# %% [markdown]
# Justification EXERCICE 7:
#
# Extraire automatiquement les infos clés du texte libre,
# Convertir la voix en texte puis extraire les données,
# Numériser l'écriture manuscrite en texte exploitable,
# Extraire les étapes et ingrédients depuis la transcription

# %%
#EXERCICE 8

df = pd.read_csv(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\train.csv')

display(df.head())

# %%
#EXERCICE 9

#DataFrame
data = {
    "Nom":    ["SOULEYMANE", "MAMADOU", "KOUADIO", "KONAN"],
    "Age":    [25, 30, 35, 28],
    "Ville":  ["Divo", "Bonoua", "Abidjan", "Yamoussokro"],
    "Salaire":[300.000, 450.000, 380.000, 420.000]
}

df = pd.DataFrame(data)

print("Mon DataFrame")
display(df)

# 2 — Exporter en Excel
df.to_excel("DataFrame.xlsx", index=False)
print("Fichier Excel créé : DataFrame.xlsx")

# 3 — Exporter en JSON
df.to_json("DataFrame.json", orient="records", indent=4)
print("Fichier JSON créé : DataFrame.json")

# %%
#EXERCICE 10

import pandas as pd

# Après avoir extrait le zip
df = pd.read_json(r'C:\Users\kmeso\Desktop\TTA_KOUAME_ASSE_SOKRY_JOSEPH\WEEK02\CVS\posts.json')

display(df.head())
